# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('sky/20.jpeg')  # Replace with your image path

# Convert to rgb and grayscale
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Threshold the grayscale image to isolate lighter areas (potential sky)
# Adjust the threshold value as needed for your specific image
_, sky_mask = cv2.threshold(gray, 100, 255, cv2.THRESH_BINARY)

# Create a mask for the sky
sky = np.zeros_like(image)
sky[np.where(sky_mask == 255)] = [0, 255, 255]  # Color the sky yellow

# Merge the original image with the colored sky
result = cv2.addWeighted(image, 1, sky, 1, 0)
result_rgb = cv2.cvtColor(result, cv2.COLOR_BGR2RGB)
# Display the image

plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(result_rgb)
plt.title('Sky Colored Yellow')

plt.show()
